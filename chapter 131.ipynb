# %%
#### Chap 1.3.1 Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('cat.jpg')

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllwindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       2 cv2.imshow('image',img)
#       3 cv2.waitKey(0)
# ----> 4 cv2.destroyAllwindows()
#
# AttributeError: module 'cv2' has no attribute 'destroyAllwindows'

# %%
img.shape
# Out:
# (182, 277, 3)

# %%
img[100, 100]
# Out:
# array([172, 191, 206], dtype=uint8)

# %%
img[100, 100, 0]=0

# %%
img[100, 100]
# Out:
# array([  0, 191, 206], dtype=uint8)

# %%
img[100,100]=0,0,0

# %%
img[0:10, 0:10]
# Out:
# array([[[ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 2, 17, 13],
#         [ 2, 17, 13],
#         [ 0, 17, 13],
#         [ 0, 17, 13],
#         [12, 29, 25],
#         [11, 28, 24]],
#
#        [[ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 2, 17, 13],
#         [ 2, 17, 13],
#         [ 0, 17, 13],
#         [ 0, 17, 13],
#         [11, 28, 24],
#         [10, 27, 23]],
#
#        [[ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 9, 26, 22],
#         [ 8, 25, 21]],
#
#        [[ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 6, 23, 19],
#         [ 6, 23, 19]],
#
#        [[ 7, 18, 15],
#         [ 7, 18, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 4, 19, 15],
#         [ 4, 19, 15],
#         [ 3, 20, 16],
#         [ 4, 21, 17]],
#
#        [[ 7, 18, 15],
#         [ 7, 18, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 4, 19, 15],
#         [ 4, 19, 15],
#         [ 3, 18, 14],
#         [ 1, 18, 14]],
#
#        [[ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 5, 20, 16],
#         [ 1, 16, 12],
#         [ 2, 17, 13]],
#
#        [[ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 0, 15, 11],
#         [ 1, 16, 12]],
#
#        [[ 5, 14, 11],
#         [ 5, 14, 11],
#         [ 4, 13, 10],
#         [ 2, 13, 10],
#         [ 4, 15, 12],
#         [ 7, 18, 15],
#         [ 9, 23, 19],
#         [12, 26, 22],
#         [ 9, 23, 19],
#         [ 8, 23, 19]],
#
#        [[ 5, 14, 11],
#         [ 4, 13, 10],
#         [ 3, 12,  9],
#         [ 3, 12,  9],
#         [ 3, 14, 11],
#         [ 7, 18, 15],
#         [11, 22, 19],
#         [11, 25, 21],
#         [ 9, 23, 19],
#         [ 8, 22, 18]]], dtype=uint8)

# %%
img[0:10, 0:10]=[0,0,0]
# Out:
# array([[[ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 2, 17, 13],
#         [ 2, 17, 13],
#         [ 0, 17, 13],
#         [ 0, 17, 13],
#         [12, 29, 25],
#         [11, 28, 24]],
#
#        [[ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 3, 17, 13],
#         [ 2, 17, 13],
#         [ 2, 17, 13],
#         [ 0, 17, 13],
#         [ 0, 17, 13],
#         [11, 28, 24],
#         [10, 27, 23]],
#
#        [[ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 9, 26, 22],
#         [ 8, 25, 21]],
#
#        [[ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 4, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 3, 18, 14],
#         [ 6, 23, 19],
#         [ 6, 23, 19]],
#
#        [[ 7, 18, 15],
#         [ 7, 18, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 4, 19, 15],
#         [ 4, 19, 15],
#         [ 3, 20, 16],
#         [ 4, 21, 17]],
#
#        [[ 7, 18, 15],
#         [ 7, 18, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 5, 19, 15],
#         [ 4, 19, 15],
#         [ 4, 19, 15],
#         [ 3, 18, 14],
#         [ 1, 18, 14]],
#
#        [[ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 5, 20, 16],
#         [ 1, 16, 12],
#         [ 2, 17, 13]],
#
#        [[ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 8, 19, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 6, 20, 16],
#         [ 0, 15, 11],
#         [ 1, 16, 12]],
#
#        [[ 5, 14, 11],
#         [ 5, 14, 11],
#         [ 4, 13, 10],
#         [ 2, 13, 10],
#         [ 4, 15, 12],
#         [ 7, 18, 15],
#         [ 9, 23, 19],
#         [12, 26, 22],
#         [ 9, 23, 19],
#         [ 8, 23, 19]],
#
#        [[ 5, 14, 11],
#         [ 4, 13, 10],
#         [ 3, 12,  9],
#         [ 3, 12,  9],
#         [ 3, 14, 11],
#         [ 7, 18, 15],
#         [11, 22, 19],
#         [11, 25, 21],
#         [ 9, 23, 19],
#         [ 8, 22, 18]]])

# %%
img[60:80, 60:80, 0]= 0
